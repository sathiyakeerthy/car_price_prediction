# %% [markdown]
# <a href="https://colab.research.google.com/github/sathiyakeerthy/car_price_prediction/blob/main/Car_Price_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("cars_price.csv")

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
from sklearn import preprocessing

# %%
Label_Encoder = preprocessing.LabelEncoder()

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df['make'] = Label_Encoder.fit_transform(df['make'])
df['make'].unique()
df['fuel-type'] = Label_Encoder.fit_transform(df['fuel-type'])
df['fuel-type'].unique()
df['aspiration'] = Label_Encoder.fit_transform(df['aspiration'])
df['aspiration'].unique()
df['num-of-doors'] = Label_Encoder.fit_transform(df['num-of-doors'])
df['num-of-doors'].unique()
df['body-style'] = Label_Encoder.fit_transform(df['body-style'])
df['body-style'].unique()
df['engine-type'] = Label_Encoder.fit_transform(df['engine-type'])
df['engine-type'].unique()
df['drive-wheels'] = Label_Encoder.fit_transform(df['drive-wheels'])
df['drive-wheels'].unique()
df['num-of-cylinders'] = Label_Encoder.fit_transform(df['num-of-cylinders'])
df['num-of-cylinders'].unique()
df['engine-location'] = Label_Encoder.fit_transform(df['engine-location'])
df['engine-location'].unique()
df['fuel-system'] = Label_Encoder.fit_transform(df['fuel-system'])
df['fuel-system'].unique()
# Out:
# array([5, 1, 4, 0, 7, 2, 3, 6])

# %% [markdown]
# #df["fuel-type"] = pd.Categorical(df["fuel-type"]).codes
# #df["aspiration"] = pd.Categorical(df["aspiration"]).codes
# #df["num-of-doors"] = pd.Categorical(df["num-of-doors"]).codes
# #df["body-style"] = pd.Categorical(df["body-style"]).codes
# #df["drive-wheels"] = pd.Categorical(df["drive-wheels"]).codes
# #df["engine-location"] = pd.Categorical(df["engine-location"]).codes
# #df["fuel-system"] = pd.Categorical(df["fuel-system"]).codes

# %%
df
# Out:
#      symboling normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 0            3                 ?     0          1           0             2
# 1            3                 ?     0          1           0             2
# 2            1                 ?     0          1           0             2
# 3            2               164     1          1           0             1
# 4            2               164     1          1           0             1
# ..         ...               ...   ...        ...         ...           ...
# 200         -1                95    21          1           0             1
# 201         -1                95    21          1           1             1
# 202         -1                95    21          1           0             1
# 203         -1                95    21          0           1             1
# 204         -1                95    21          1           1             1
#
# ...

# %%
df['wheel-base']=df['wheel-base'].astype(int)
df['length']=df['wheel-base'].astype(int)
df['width']=df['wheel-base'].astype(int)
df['bore']=df['wheel-base'].astype(int)
df['stroke']=df['wheel-base'].astype(int)
df['engine-type']=df['engine-type'].astype(int)
df['num-of-cylinders']=df['num-of-cylinders'].astype(int)
df['compression-ratio']=df['compression-ratio'].astype(int)
df
# Out:
#      symboling normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 0            3                 ?     0          1           0             2
# 1            3                 ?     0          1           0             2
# 2            1                 ?     0          1           0             2
# 3            2               164     1          1           0             1
# 4            2               164     1          1           0             1
# ..         ...               ...   ...        ...         ...           ...
# 200         -1                95    21          1           0             1
# 201         -1                95    21          1           1             1
# 202         -1                95    21          1           0             1
# 203         -1                95    21          0           1             1
# 204         -1                95    21          1           1             1
#
# ...

# %%
df.isna()
# Out:
#      symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0        False              False  False      False       False         False
# 1        False              False  False      False       False         False
# 2        False              False  False      False       False         False
# 3        False              False  False      False       False         False
# 4        False              False  False      False       False         False
# ..         ...                ...    ...        ...         ...           ...
# 200      False              False  False      False       False         False
# 201      False              False  False      False       False         False
# 202      False              False  False      False       False         False
# 203      False              False  False      False       False         False
# 204      False              False  False      False       False         False
#
# ...

# %%
df['normalized-losses'] = df['normalized-losses'].replace('?',np.nan)
df['bore'] = df['bore'].replace('?',np.nan)
df['stroke'] = df['stroke'].replace('?',np.nan)
df['horsepower'] = df['horsepower'].replace('?',np.nan)
df['peak-rpm'] = df['peak-rpm'].replace('?',np.nan)
df['price'] = df['price'].replace('?',np.nan)
df
# Out:
#      symboling normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 0            3               NaN     0          1           0             2
# 1            3               NaN     0          1           0             2
# 2            1               NaN     0          1           0             2
# 3            2               164     1          1           0             1
# 4            2               164     1          1           0             1
# ..         ...               ...   ...        ...         ...           ...
# 200         -1                95    21          1           0             1
# 201         -1                95    21          1           1             1
# 202         -1                95    21          1           0             1
# 203         -1                95    21          0           1             1
# 204         -1                95    21          1           1             1
#
# ...

# %%
df['normalized-losses'].fillna(0,inplace=True)
df['bore'].fillna(0,inplace=True)
df['stroke'].fillna(0,inplace=True)
df['horsepower'].fillna(0,inplace=True)
df['peak-rpm'].fillna(0,inplace=True)
df['price'].fillna(0,inplace=True)
df
# Out:
#      symboling normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 0            3                 0     0          1           0             2
# 1            3                 0     0          1           0             2
# 2            1                 0     0          1           0             2
# 3            2               164     1          1           0             1
# 4            2               164     1          1           0             1
# ..         ...               ...   ...        ...         ...           ...
# 200         -1                95    21          1           0             1
# 201         -1                95    21          1           1             1
# 202         -1                95    21          1           0             1
# 203         -1                95    21          0           1             1
# 204         -1                95    21          1           1             1
#
# ...

# %%
df.to_csv("keerthi.csv",index=False)

# %%
df.corr()
# Out:
#                    symboling      make  fuel-type  aspiration  num-of-doors  \
# symboling           1.000000 -0.118794   0.194311   -0.059866      0.645492
# make               -0.118794  1.000000  -0.113191    0.054265     -0.127416
# fuel-type           0.194311 -0.113191   1.000000   -0.401397      0.207665
# aspiration         -0.059866  0.054265  -0.401397    1.000000     -0.066737
# num-of-doors        0.645492 -0.127416   0.207665   -0.066737      1.000000
# body-style         -0.596135  0.089494  -0.147853    0.063028     -0.670198
# drive-wheels       -0.041671 -0.004317  -0.132257    0.066465      0.112398
# engine-location     0.212471  0.054608   0.040070   -0.057191      0.136578
# wheel-base         -0.533322  0.084751  -0.304407    0.255692     -0.415741
# length             -0.533322  0.084751  -0.304407    0.255692     -0.415741
# width              -0.533322  0.084751  -0.304407    0.255692     -0.415741
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df.shape
# Out:
# (205, 26)

# %%
x = df.drop(['price'],axis = 1)
x
# Out:
#      symboling normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 0            3                 0     0          1           0             2
# 1            3                 0     0          1           0             2
# 2            1                 0     0          1           0             2
# 3            2               164     1          1           0             1
# 4            2               164     1          1           0             1
# ..         ...               ...   ...        ...         ...           ...
# 200         -1                95    21          1           0             1
# 201         -1                95    21          1           1             1
# 202         -1                95    21          1           0             1
# 203         -1                95    21          0           1             1
# 204         -1                95    21          1           1             1
#
# ...

# %%
y = df['price']
y
# Out:
# 0      13495
# 1      16500
# 2      16500
# 3      13950
# 4      17450
#        ...
# 200    16845
# 201    19045
# 202    21485
# 203    22470
# 204    22625
# Name: price, Length: 205, dtype: object

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2)

# %%
xtrain,xtest,ytrain,ytest
# Out:
# (     symboling normalized-losses  make  fuel-type  aspiration  num-of-doors  \
#  144          0               102    18          1           0             1
#  107          0               161    13          1           0             1
#  4            2               164     1          1           0             1
#  46           2                 0     6          1           0             2
#  139          2                83    18          1           0             2
#  ..         ...               ...   ...        ...         ...           ...
#  20           0                81     3          1           0             1
#  72           3               142     9          1           0             2
#  183          2               122    20          1           0             2
#  105          3               194    12          1           1             2
#  88          -1               137    11          1           0             1
#
# ...

# %%
final_model = LinearRegression()

# %%
final_model.fit(xtrain,ytrain,sample_weight=2)
# Out:
# LinearRegression()

# %%
y_pred = final_model.predict(x)

# %%
y_pred
# Out:
# array([13654.22677149, 13654.22677149, 17178.23764079, 13323.8130567 ,
#        14688.18822938, 13621.99448697, 17117.65736095, 16541.6639247 ,
#        19125.6491587 , 11138.15981907, 13801.68401223, 13910.32116601,
#        18859.87665125, 20087.78668968, 22587.711682  , 26197.62974609,
#        24736.08665196, 28191.75250259,  3307.36523443,  6310.78858891,
#         6223.82840285,  6242.36650578,  5950.00807793,  9625.67694316,
#         7238.48944252,  6549.52315768,  6549.52315768, 11109.54929782,
#        13656.19292317, 16920.0347116 ,  3861.83930892,  5912.61588835,
#         5951.59197177,  7876.40845949,  7928.75935678,  9023.95470698,
#         9991.69858875, 10114.76600558, 10288.17835287, 10962.76016037,
#        11185.25147388, 12550.13044692,  7581.50780961, 11067.8190077 ,
#         4997.72472958,  5690.53780879, 15495.15776356, 33439.68168003,
#        33279.1197968 , 38564.96402855,  7334.59592867,  5984.60572167,
# ...

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
mse = mean_squared_error(y,y_pred)
mae = mean_absolute_error(y,y_pred)
r2_score = r2_score(y,y_pred)

# %%
mse
# Out:
# 10085019.093471458

# %%
mae
# Out:
# 2214.962843625087

# %%
r2_score
# Out:
# 0.8447325042041843
